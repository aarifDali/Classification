# %%
import pandas as pd

# %%
df = pd.read_csv('HRDataset_v14.csv')
df.head()
# Out:
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0       Adinolfi, Wilson  K  10026          0                0         1
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
# 2         Akinkuolie, Sarah  10196          1                1         0
# 3              Alagbe,Trina  10088          1                1         0
# 4          Anderson, Carol   10069          0                2         0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0            1       5            4                       0   62506  ...
# 1            5       3            3                       0  104437  ...
# 2            5       5            3                       0   64955  ...
# 3            1       5            3                       0   64991  ...
# 4            5       5            3                       0   50825  ...
#
#       ManagerName  ManagerID RecruitmentSource PerformanceScore  \
# ...

# %%
df.columns
# Out:
# Index(['Employee_Name', 'EmpID', 'MarriedID', 'MaritalStatusID', 'GenderID',
#        'EmpStatusID', 'DeptID', 'PerfScoreID', 'FromDiversityJobFairID',
#        'Salary', 'Termd', 'PositionID', 'Position', 'State', 'Zip', 'DOB',
#        'Sex', 'MaritalDesc', 'CitizenDesc', 'HispanicLatino', 'RaceDesc',
#        'DateofHire', 'DateofTermination', 'TermReason', 'EmploymentStatus',
#        'Department', 'ManagerName', 'ManagerID', 'RecruitmentSource',
#        'PerformanceScore', 'EngagementSurvey', 'EmpSatisfaction',
#        'SpecialProjectsCount', 'LastPerformanceReview_Date', 'DaysLateLast30',
#        'Absences'],
#       dtype='object')

# %%
df1 = df.groupby(['GenderID'])

# %%
df1.head()
# Out:
#                Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0        Adinolfi, Wilson  K  10026          0                0         1
# 1   Ait Sidi, Karthikeyan     10084          1                1         1
# 2          Akinkuolie, Sarah  10196          1                1         0
# 3               Alagbe,Trina  10088          1                1         0
# 4           Anderson, Carol   10069          0                2         0
# 5          Anderson, Linda    10002          0                0         0
# 6            Andreola, Colby  10194          0                0         0
# 7                Athwal, Sam  10062          0                4         1
# 9         Bacong, Alejandro   10250          0                2         1
# 11           Barbara, Thomas  10242          1                1         1
#
#     EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0             1       5            4                       0   62506  ...
# ...

# %%
cond = (df['GenderID'] == 1)

# %%
df.loc[cond, 'Employee_Name'].head(10)
# Out:
# 0          Adinolfi, Wilson  K
# 1     Ait Sidi, Karthikeyan
# 7                  Athwal, Sam
# 9           Bacong, Alejandro
# 11             Barbara, Thomas
# 12            Barbossa, Hector
# 13        Barone, Francesco  A
# 14               Barton, Nader
# 15               Bates, Norman
# 19               Becker, Scott
# Name: Employee_Name, dtype: object

# %%
cond = df.sort_values(by='EmpSatisfaction', ascending=False)
cond
# Out:
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0       Adinolfi, Wilson  K  10026          0                0         1
# 149   Khemmich, Bartholemew  10231          0                0         1
# 129  Homberger, Adrienne  J  10195          1                1         0
# 130           Horton, Jayne  10112          0                0         0
# 134          Hunts, Julissa  10201          0                0         0
# ..                      ...    ...        ...              ...       ...
# 137       Immediato, Walter  10289          1                1         1
# 205            O'hare, Lynn  10303          0                0         0
# 188             Miller, Ned  10298          0                0         1
# 83           Erilus, Angela  10299          0                3         0
# 72        Dietrich, Jenna    10304          0                0         0
#
#      EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# ...

# %%
pd.set_option('display.max_rows', df.shape[0]+1)

# %%
gender = ['F']
mask = df['Sex'].isin(gender)
df.loc[mask]
# Out:
#                  Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 2            Akinkuolie, Sarah  10196          1                1         0
# 3                 Alagbe,Trina  10088          1                1         0
# 4             Anderson, Carol   10069          0                2         0
# 5            Anderson, Linda    10002          0                0         0
# 6              Andreola, Colby  10194          0                0         0
# 8             Bachiochi, Linda  10114          0                0         0
# 10        Baczenski, Rachael    10252          1                1         0
# 16            Beak, Kimberly    10023          1                1         0
# 17         Beatrice, Courtney   10055          0                0         0
# 18               Becker, Renee  10245          0                0         0
# 21             Biden, Lowan  M  10226          0                2         0
# ...

# %%
df['Sex']
# Out:
# 0      M
# 1      M
# 2       F
# 3       F
# 4       F
# 5       F
# 6       F
# 7      M
# 8       F
# 9      M
# 10      F
# 11     M
# 12     M
# 13     M
# 14     M
# 15     M
# 16      F
# 17      F
# 18      F
# 19     M
# 20     M
# 21      F
# 22      F
# 23      F
# 24      F
# 25     M
# 26      F
# 27     M
# 28      F
# 29      F
# 30     M
# 31      F
# 32      F
# 33      F
# 34     M
# 35     M
# 36     M
# 37      F
# 38     M
# 39      F
# 40      F
# 41      F
# 42     M
# 43      F
# 44     M
# 45     M
# 46      F
# 47      F
# 48     M
# 49      F
# 50     M
# 51     M
# 52     M
# 53     M
# 54     M
# 55     M
# 56      F
# 57     M
# 58      F
# 59     M
# 60      F
# 61      F
# 62      F
# 63     M
# 64     M
# 65     M
# 66      F
# 67     M
# 68      F
# 69     M
# 70     M
# 71     M
# 72      F
# 73      F
# 74      F
# 75      F
# 76     M
# 77      F
# 78      F
# 79      F
# 80      F
# 81     M
# 82     M
# 83      F
# 84     M
# 85      F
# ...

# %%
mask1 = df['Employee_Name'].str.contains('Alex', na = False)
df.loc[mask1, ['Employee_Name', 'Sex', 'GenderID']]
# Out:
#            Employee_Name Sex  GenderID
# 67         Delarge, Alex  M          1
# 95         Forrest, Alex  M          1
# 105         Gilles, Alex  M          1
# 152  Kirill, Alexandra     F         0

# %%
df['EmpSatisfaction'].value_counts()
# Out:
# 3    108
# 5     98
# 4     94
# 2      9
# 1      2
# Name: EmpSatisfaction, dtype: int64

# %%
Satisfaction5 = df['EmpSatisfaction'] == 5
df.loc[Satisfaction5]
# Out:
#                  Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0          Adinolfi, Wilson  K  10026          0                0         1
# 3                 Alagbe,Trina  10088          1                1         0
# 5            Anderson, Linda    10002          0                0         0
# 9           Bacong, Alejandro   10250          0                2         1
# 14               Barton, Nader  10066          0                2         1
# 17         Beatrice, Courtney   10055          0                0         0
# 24             Bondwell, Betsy  10267          0                0         0
# 25                Booth, Frank  10199          0                0         1
# 31          Bugali, Josephine   10203          0                3         0
# 32            Bunbury, Jessica  10188          1                1         0
# 34          Burkett, Benjamin   10181          1                1         1
# ...

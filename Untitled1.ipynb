# %%
import pandas as pd

# %%
df = pd.read_csv('HRDataset_v14.csv')

# %%
df
# Out:
#                 Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0         Adinolfi, Wilson  K  10026          0                0         1
# 1    Ait Sidi, Karthikeyan     10084          1                1         1
# 2           Akinkuolie, Sarah  10196          1                1         0
# 3                Alagbe,Trina  10088          1                1         0
# 4            Anderson, Carol   10069          0                2         0
# ..                        ...    ...        ...              ...       ...
# 306            Woodson, Jason  10135          0                0         1
# 307        Ybarra, Catherine   10301          0                0         0
# 308          Zamora, Jennifer  10010          0                0         0
# 309               Zhou, Julia  10043          0                0         0
# 310             Zima, Colleen  10271          0                4         0
#
# ...

# %%
pd.set_option('display.max_rows', df.shape[0]+1)

# %%
df
# Out:
#                  Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0          Adinolfi, Wilson  K  10026          0                0         1
# 1     Ait Sidi, Karthikeyan     10084          1                1         1
# 2            Akinkuolie, Sarah  10196          1                1         0
# 3                 Alagbe,Trina  10088          1                1         0
# 4             Anderson, Carol   10069          0                2         0
# 5            Anderson, Linda    10002          0                0         0
# 6              Andreola, Colby  10194          0                0         0
# 7                  Athwal, Sam  10062          0                4         1
# 8             Bachiochi, Linda  10114          0                0         0
# 9           Bacong, Alejandro   10250          0                2         1
# 10        Baczenski, Rachael    10252          1                1         0
# ...

# %%
mask = ((df['Sex'] == 'F') & (df['Salary'] > 100000))

# %%
df[mask]
# Out:
#          Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 18       Becker, Renee  10245          0                0         0
# 26   Boutwell, Bonalyn  10081          1                1         0
# 39    Carr, Claudia  N  10082          0                0         0
# 66   Del Bosque, Keyla  10155          0                0         0
# 108      Goble, Taisha  10246          0                0         0
# 131    Houlihan, Debra  10272          1                1         0
# 144   Johnson, Noelle   10156          1                1         0
# 150        King, Janet  10089          1                1         0
# 180     Martin, Sandra  10110          0                0         0
# 239   Roehrich, Bianca  10149          0                0         0
# 240       Roper, Katie  10086          0                0         0
# 299    Warfield, Sarah  10127          0                4         0
# 308   Zamora, Jennifer  10010          0                0         0
#
# ...

# %%
df['Salary'].head()
# Out:
# 0     62506
# 1    104437
# 2     64955
# 3     64991
# 4     50825
# Name: Salary, dtype: int64

# %%
df.columns
# Out:
# Index(['Employee_Name', 'EmpID', 'MarriedID', 'MaritalStatusID', 'GenderID',
#        'EmpStatusID', 'DeptID', 'PerfScoreID', 'FromDiversityJobFairID',
#        'Salary', 'Termd', 'PositionID', 'Position', 'State', 'Zip', 'DOB',
#        'Sex', 'MaritalDesc', 'CitizenDesc', 'HispanicLatino', 'RaceDesc',
#        'DateofHire', 'DateofTermination', 'TermReason', 'EmploymentStatus',
#        'Department', 'ManagerName', 'ManagerID', 'RecruitmentSource',
#        'PerformanceScore', 'EngagementSurvey', 'EmpSatisfaction',
#        'SpecialProjectsCount', 'LastPerformanceReview_Date', 'DaysLateLast30',
#        'Absences'],
#       dtype='object')

# %%
df['Department'].value_counts()
# Out:
# Production              209
# IT/IS                    50
# Sales                    31
# Software Engineering     11
# Admin Offices             9
# Executive Office          1
# Name: Department, dtype: int64

# %%
dep_group = df.groupby(['Department'])

# %%
dep_group.describe()
# Out:
#                       EmpID                                             \
#                       count          mean        std      min      25%
# Department
# Admin Offices           9.0  10121.333333  67.242100  10038.0  10080.0
# Executive Office        1.0  10089.000000        NaN  10089.0  10089.0
# IT/IS                  50.0  10150.780000  82.802024  10008.0  10084.5
# Production            209.0  10157.363636  92.342026  10001.0  10071.0
# Sales                  31.0  10178.548387  92.525974  10006.0  10115.0
# Software Engineering   11.0  10124.727273  77.783148  10005.0  10093.5
#
#                                                 MarriedID            ...  \
#                           50%      75%      max     count      mean  ...
# Department                                                           ...
# Admin Offices         10134.0  10153.0  10238.0       9.0  0.666667  ...
# Executive Office      10089.0  10089.0  10089.0       1.0  1.000000  ...
# ...

# %%
gender_mask = (df['GenderID'] == 1)

# %%
df.loc[gender_mask, ['Employee_Name', 'Sex']]
# Out:
#                 Employee_Name Sex
# 0         Adinolfi, Wilson  K  M
# 1    Ait Sidi, Karthikeyan     M
# 7                 Athwal, Sam  M
# 9          Bacong, Alejandro   M
# 11            Barbara, Thomas  M
# 12           Barbossa, Hector  M
# 13       Barone, Francesco  A  M
# 14              Barton, Nader  M
# 15              Bates, Norman  M
# 19              Becker, Scott  M
# 20            Bernstein, Sean  M
# 25               Booth, Frank  M
# 27             Bozzi, Charles  M
# 30         Buccheri, Joseph    M
# 34         Burkett, Benjamin   M
# 35                 Cady, Max   M
# 36             Candie, Calvin  M
# 38           Carey, Michael    M
# 42          Champaigne, Brian  M
# 44          Chang, Donovan  E  M
# 45             Chigurh, Anton  M
# 48              Clayton, Rick  M
# 50                Close, Phil  M
# 51            Clukey, Elijian  M
# 52              Cockel, James  M
# 53              Cole, Spencer  M
# 54          Corleone, Michael  M
# ...

# %%
sort_satisfaction = df.sort_values(by = 'EmpSatisfaction', ascending=True)

# %%
sort_satisfaction[[ 'Employee_Name','Sex','EmpSatisfaction',]]
# Out:
#                  Employee_Name Sex  EmpSatisfaction
# 83              Erilus, Angela   F                1
# 72           Dietrich, Jenna     F                1
# 263           Sparks, Taylor     F                2
# 267         Stansfield, Norman  M                 2
# 205               O'hare, Lynn   F                2
# 54           Corleone, Michael  M                 2
# 137          Immediato, Walter  M                 2
# 188                Miller, Ned  M                 2
# 307         Ybarra, Catherine    F                2
# 69             Desimone, Carl   M                 2
# 29                  Brown, Mia   F                2
# 252            Shepard, Anita    F                3
# 277            Tejeda, Lenora    F                3
# 179             Mangal, Debbie   F                3
# 94              Foreman, Tanya   F                3
# 275               Tannen, Biff  M                 3
# 97           Foster-Baker, Amy   F                3
# ...

# %%
Satis_group = df.groupby(['EmpSatisfaction'])
Satis_group.mean()
# Out:
#                         EmpID  MarriedID  MaritalStatusID  GenderID  \
# EmpSatisfaction
# 1                10301.500000   0.000000         1.500000  0.000000
# 2                10292.222222   0.555556         0.777778  0.555556
# 3                10151.361111   0.500000         0.722222  0.490741
# 4                10154.776596   0.340426         0.957447  0.372340
# 5                10146.806122   0.336735         0.755102  0.428571
#
#                  EmpStatusID    DeptID  PerfScoreID  FromDiversityJobFairID  \
# EmpSatisfaction
# 1                   1.000000  5.500000     1.000000                0.000000
# 2                   2.666667  4.666667     1.444444                0.111111
# 3                   2.277778  4.546296     2.981481                0.074074
# 4                   2.638298  4.563830     3.042553                0.170213
# 5                   2.285714  4.704082     3.091837                0.040816
#
# ...

# %%
Satis_group.get_group(5)
# Out:
#                  Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0          Adinolfi, Wilson  K  10026          0                0         1
# 3                 Alagbe,Trina  10088          1                1         0
# 5            Anderson, Linda    10002          0                0         0
# 9           Bacong, Alejandro   10250          0                2         1
# 14               Barton, Nader  10066          0                2         1
# 17         Beatrice, Courtney   10055          0                0         0
# 24             Bondwell, Betsy  10267          0                0         0
# 25                Booth, Frank  10199          0                0         1
# 31          Bugali, Josephine   10203          0                3         0
# 32            Bunbury, Jessica  10188          1                1         0
# 34          Burkett, Benjamin   10181          1                1         1
# ...

# %%
gender_group = df.groupby(['Sex'])

# %%
gender_group

# %%
df[['GenderID', 'Sex']]
# Out:
#      GenderID Sex
# 0           1  M
# 1           1  M
# 2           0   F
# 3           0   F
# 4           0   F
# 5           0   F
# 6           0   F
# 7           1  M
# 8           0   F
# 9           1  M
# 10          0   F
# 11          1  M
# 12          1  M
# 13          1  M
# 14          1  M
# 15          1  M
# 16          0   F
# 17          0   F
# 18          0   F
# 19          1  M
# 20          1  M
# 21          0   F
# 22          0   F
# 23          0   F
# 24          0   F
# 25          1  M
# 26          0   F
# 27          1  M
# 28          0   F
# 29          0   F
# 30          1  M
# 31          0   F
# 32          0   F
# 33          0   F
# 34          1  M
# 35          1  M
# 36          1  M
# 37          0   F
# 38          1  M
# 39          0   F
# 40          0   F
# 41          0   F
# 42          1  M
# 43          0   F
# 44          1  M
# 45          1  M
# 46          0   F
# 47          0   F
# 48          1  M
# 49          0   F
# ...

# %%
gender_group['Salary'].mean()
# Out:
# Sex
# F     67786.727273
# M     70629.400000
# Name: Salary, dtype: float64

# %%
# gender_group['PerformanceScore'].mean()
df['PerformanceScore'].value_counts()
# Out:
# Fully Meets          243
# Exceeds               37
# Needs Improvement     18
# PIP                   13
# Name: PerformanceScore, dtype: int64

# %%
import pandas as pd

# %%
df = pd.read_csv('HRDataset_v14.csv')

# %%
df.head()
# Out:
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0       Adinolfi, Wilson  K  10026          0                0         1
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
# 2         Akinkuolie, Sarah  10196          1                1         0
# 3              Alagbe,Trina  10088          1                1         0
# 4          Anderson, Carol   10069          0                2         0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0            1       5            4                       0   62506  ...
# 1            5       3            3                       0  104437  ...
# 2            5       5            3                       0   64955  ...
# 3            1       5            3                       0   64991  ...
# 4            5       5            3                       0   50825  ...
#
#       ManagerName  ManagerID RecruitmentSource PerformanceScore  \
# ...

# %%
df.columns
# Out:
# Index(['Employee_Name', 'EmpID', 'MarriedID', 'MaritalStatusID', 'GenderID',
#        'EmpStatusID', 'DeptID', 'PerfScoreID', 'FromDiversityJobFairID',
#        'Salary', 'Termd', 'PositionID', 'Position', 'State', 'Zip', 'DOB',
#        'Sex', 'MaritalDesc', 'CitizenDesc', 'HispanicLatino', 'RaceDesc',
#        'DateofHire', 'DateofTermination', 'TermReason', 'EmploymentStatus',
#        'Department', 'ManagerName', 'ManagerID', 'RecruitmentSource',
#        'PerformanceScore', 'EngagementSurvey', 'EmpSatisfaction',
#        'SpecialProjectsCount', 'LastPerformanceReview_Date', 'DaysLateLast30',
#        'Absences'],
#       dtype='object')

# %%
list(df.columns)
# Out:
# ['Employee_Name',
#  'EmpID',
#  'MarriedID',
#  'MaritalStatusID',
#  'GenderID',
#  'EmpStatusID',
#  'DeptID',
#  'PerfScoreID',
#  'FromDiversityJobFairID',
#  'Salary',
#  'Termd',
#  'PositionID',
#  'Position',
#  'State',
#  'Zip',
#  'DOB',
#  'Sex',
#  'MaritalDesc',
#  'CitizenDesc',
#  'HispanicLatino',
#  'RaceDesc',
#  'DateofHire',
#  'DateofTermination',
#  'TermReason',
#  'EmploymentStatus',
#  'Department',
#  'ManagerName',
#  'ManagerID',
#  'RecruitmentSource',
#  'PerformanceScore',
#  'EngagementSurvey',
#  'EmpSatisfaction',
#  'SpecialProjectsCount',
#  'LastPerformanceReview_Date',
#  'DaysLateLast30',
#  'Absences']

# %%
sex_group = df.groupby('Sex')

# %%
sex_group.get_group('F')[['Employee_Name', 'Salary']]
# Out:
#           Employee_Name  Salary
# 2     Akinkuolie, Sarah   64955
# 3          Alagbe,Trina   64991
# 4      Anderson, Carol    50825
# 5     Anderson, Linda     57568
# 6       Andreola, Colby   95660
# ..                  ...     ...
# 305       Wolk, Hang  T   60446
# 307  Ybarra, Catherine    48513
# 308    Zamora, Jennifer  220450
# 309         Zhou, Julia   89292
# 310       Zima, Colleen   45046
#
# [176 rows x 2 columns]

# %%
df['Salary'].idxmax()
# Out:
# 150

# %%
# df[['First_Name', 'Last_Name']] = df['Employee_Name'].apply(lambda x: pd.Series(x.split(',')))

# %%
df.head()
# Out:
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0       Adinolfi, Wilson  K  10026          0                0         1
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
# 2         Akinkuolie, Sarah  10196          1                1         0
# 3              Alagbe,Trina  10088          1                1         0
# 4          Anderson, Carol   10069          0                2         0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0            1       5            4                       0   62506  ...
# 1            5       3            3                       0  104437  ...
# 2            5       5            3                       0   64955  ...
# 3            1       5            3                       0   64991  ...
# 4            5       5            3                       0   50825  ...
#
#       ManagerName  ManagerID RecruitmentSource PerformanceScore  \
# ...

# %%
Name = []
F_name = []
L_name = []
for i in df['Employee_Name']:
    Name = str.split(i, ',')
    F_name.append(Name[0])
    L_name.append(Name[1])

df['First Name'] = F_name
df['Last Name'] = L_name

# %%
df.head()
# Out:
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0       Adinolfi, Wilson  K  10026          0                0         1
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
# 2         Akinkuolie, Sarah  10196          1                1         0
# 3              Alagbe,Trina  10088          1                1         0
# 4          Anderson, Carol   10069          0                2         0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0            1       5            4                       0   62506  ...
# 1            5       3            3                       0  104437  ...
# 2            5       5            3                       0   64955  ...
# 3            1       5            3                       0   64991  ...
# 4            5       5            3                       0   50825  ...
#
#    RecruitmentSource  PerformanceScore EngagementSurvey EmpSatisfaction  \
# ...

# %%
df['Department'].value_counts()
# Out:
# Production              209
# IT/IS                    50
# Sales                    31
# Software Engineering     11
# Admin Offices             9
# Executive Office          1
# Name: Department, dtype: int64

# %%
dep_group = df.groupby('Department')

# %%
Sales = dep_group.get_group('Sales')

# %%
Sales['Salary'].idxmax()
# Out:
# 131

# %%
df.iloc[131, [0, 9]]
# Out:
# Employee_Name    Houlihan, Debra
# Salary                    180000
# Name: 131, dtype: object

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(df['Department'])
plt.xticks(rotation = 'vertical')
# Out:
# ([0, 1, 2, 3, 4, 5],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
dep_group.apply(lambda df: df.loc[df['Salary'].idxmax(), :])
# Out:
#                           Employee_Name  EmpID  MarriedID  MaritalStatusID  \
# Department
# Admin Offices         Boutwell, Bonalyn  10081          1                1
# Executive Office            King, Janet  10089          1                1
# IT/IS                  Zamora, Jennifer  10010          0                0
# Production               Corleone, Vito  10019          0                0
# Sales                   Houlihan, Debra  10272          1                1
# Software Engineering   Patronick, Lucas  10005          0                0
#
#                       GenderID  EmpStatusID  DeptID  PerfScoreID  \
# Department
# Admin Offices                0            1       1            3
# Executive Office             0            1       2            3
# IT/IS                        0            1       3            4
# Production                   1            1       5            4
# Sales                        0            1       6            3
# ...
